# %%
# %cd /kaggle/working
# !rm -fr PolishLawLLM-Benchmark/

# %%
# !git clone -b feat-pllum-integration https://github.com/PiotrTyrakowski/PolishLawLLM-Benchmark.git

# %%
# %cd PolishLawLLM-Benchmark/
# !pip install -e .

# %% [markdown]
# Before running next cell make sure to upload ```/exams``` folder into ```/content/data``` directory

# %%
from pathlib import Path
from src.benchmark_framework import get_llm_model
from src.benchmark_framework import get_manager
from src.benchmark_framework.configs.model_config import ModelConfig

model_name = "CYFRAGOVPL/Llama-PLLuM-8B-chat"
dataset_name = "exams"
tasks_path = Path("/kaggle/input/exams2024/data")

model_config = ModelConfig(quantize="4bit", batch_size=8)
model = get_llm_model(model_name, model_config)
manager = get_manager(dataset_name, model, tasks_path)

# %%
from src.benchmark_framework import BenchmarkRunner

runner = BenchmarkRunner(manager)
result = runner.run()
print(result)
